# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import datetime as dt
import re
import json
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## Getting data from Web API

# %% [markdown]
# Set parameters

# %%
#https://dstock.vndirect.com.vn/lich-su-gia/TCB
ticker = 'TCB'
start_date = '2020-01-01'
end_date = dt.datetime.strftime(dt.datetime.today(), '%Y-%m-%d')
delta = dt.datetime.strptime(end_date, '%Y-%m-%d') - dt.datetime.strptime(start_date, '%Y-%m-%d')

# %% [markdown]
# Web API

# %%
price_api = f'https://finfo-api.vndirect.com.vn/v4/stock_prices?sort=date&q=code:{ticker}~date:gte:{start_date}~date:lte:{end_date}&size={delta.days+1}&page=1'

# %% [markdown]
# Get data API

# %%
HEADERS = {'User-Agent': 'Mozilla'}
res = requests.get(price_api, headers=HEADERS)
res
# Out:
# <Response [200]>

# %%
res.text[:500]
# Out:
# '{"data":[{"code":"VND","date":"2022-04-08","time":"15:04:02","floor":"HOSE","type":"STOCK","basicPrice":35.0,"ceilingPrice":37.45,"floorPrice":32.55,"open":35.0,"high":36.0,"low":34.55,"close":35.1,"average":35.16,"adOpen":35.0,"adHigh":36.0,"adLow":34.55,"adClose":35.1,"adAverage":35.16,"nmVolume":1.79893E7,"nmValue":6.3251999E11,"ptVolume":0.0,"ptValue":0.0,"change":0.1,"adChange":0.1,"pctChange":0.2857},{"code":"VND","date":"2022-04-07","time":"15:04:01","floor":"HOSE","type":"STOCK","basicPr'

# %%
data = res.json()['data']  
data
# Out:
# [{'code': 'VND',
#   'date': '2022-04-08',
#   'time': '15:04:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 35.0,
#   'ceilingPrice': 37.45,
#   'floorPrice': 32.55,
#   'open': 35.0,
#   'high': 36.0,
#   'low': 34.55,
#   'close': 35.1,
#   'average': 35.16,
#   'adOpen': 35.0,
#   'adHigh': 36.0,
#   'adLow': 34.55,
#   'adClose': 35.1,
#   'adAverage': 35.16,
#   'nmVolume': 17989300.0,
#   'nmValue': 632519990000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.1,
#   'adChange': 0.1,
#   'pctChange': 0.2857},
#  {'code': 'VND',
#   'date': '2022-04-07',
#   'time': '15:04:01',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 35.5,
#   'ceilingPrice': 37.95,
#   'floorPrice': 33.05,
#   'open': 35.5,
#   'high': 37.0,
#   'low': 35.0,
#   'close': 35.0,
#   'average': 36.02,
#   'adOpen': 35.5,
#   'adHigh': 37.0,
#   'adLow': 35.0,
#   'adClose': 35.0,
#   'adAverage': 36.02,
#   'nmVolume': 23236900.0,
#   'nmValue': 836968205000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.5,
#   'adChange': -0.5,
#   'pctChange': -1.4085},
#  {'code': 'VND',
#   'date': '2022-04-06',
#   'time': '15:04:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 34.6,
#   'ceilingPrice': 37.0,
#   'floorPrice': 32.2,
#   'open': 34.0,
#   'high': 36.0,
#   'low': 34.0,
#   'close': 35.5,
#   'average': 35.23,
#   'adOpen': 34.0,
#   'adHigh': 36.0,
#   'adLow': 34.0,
#   'adClose': 35.5,
#   'adAverage': 35.23,
#   'nmVolume': 18821500.0,
#   'nmValue': 663019675000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.9,
#   'adChange': 0.9,
#   'pctChange': 2.6012},
#  {'code': 'VND',
#   'date': '2022-04-05',
#   'time': '15:04:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 33.9,
#   'ceilingPrice': 36.25,
#   'floorPrice': 31.55,
#   'open': 34.1,
#   'high': 36.1,
#   'low': 34.1,
#   'close': 34.6,
#   'average': 35.2,
#   'adOpen': 34.1,
#   'adHigh': 36.1,
#   'adLow': 34.1,
#   'adClose': 34.6,
#   'adAverage': 35.2,
#   'nmVolume': 17035800.0,
#   'nmValue': 599641800000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.7,
#   'adChange': 0.7,
#   'pctChange': 2.0649},
#  {'code': 'VND',
#   'date': '2022-04-04',
#   'time': '15:04:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 31.7,
#   'ceilingPrice': 33.9,
#   'floorPrice': 29.5,
#   'open': 32.4,
#   'high': 33.9,
#   'low': 32.35,
#   'close': 33.9,
#   'average': 33.55,
#   'adOpen': 32.4,
#   'adHigh': 33.9,
#   'adLow': 32.35,
#   'adClose': 33.9,
#   'adAverage': 33.55,
#   'nmVolume': 28162500.0,
#   'nmValue': 944774610000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 2.2,
#   'adChange': 2.2,
#   'pctChange': 6.9401},
#  {'code': 'VND',
#   'date': '2022-04-01',
#   'time': '15:04:01',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 30.5,
#   'ceilingPrice': 32.6,
#   'floorPrice': 28.4,
#   'open': 30.5,
#   'high': 31.8,
#   'low': 30.1,
#   'close': 31.7,
#   'average': 30.89,
#   'adOpen': 30.5,
#   'adHigh': 31.8,
#   'adLow': 30.1,
#   'adClose': 31.7,
#   'adAverage': 30.89,
#   'nmVolume': 7846800.0,
#   'nmValue': 242420415000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.2,
#   'adChange': 1.2,
#   'pctChange': 3.9344},
#  {'code': 'VND',
#   'date': '2022-03-31',
#   'time': '15:03:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 30.95,
#   'ceilingPrice': 33.1,
#   'floorPrice': 28.8,
#   'open': 31.1,
#   'high': 31.25,
#   'low': 30.3,
#   'close': 30.5,
#   'average': 30.76,
#   'adOpen': 31.1,
#   'adHigh': 31.25,
#   'adLow': 30.3,
#   'adClose': 30.5,
#   'adAverage': 30.76,
#   'nmVolume': 4554400.0,
#   'nmValue': 140074085000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.45,
#   'adChange': -0.45,
#   'pctChange': -1.454},
#  {'code': 'VND',
#   'date': '2022-03-30',
#   'time': '15:03:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 30.9,
#   'ceilingPrice': 33.05,
#   'floorPrice': 28.75,
#   'open': 30.6,
#   'high': 31.45,
#   'low': 30.3,
#   'close': 30.95,
#   'average': 30.88,
#   'adOpen': 30.6,
#   'adHigh': 31.45,
#   'adLow': 30.3,
#   'adClose': 30.95,
#   'adAverage': 30.88,
#   'nmVolume': 5877000.0,
#   'nmValue': 181466180000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.05,
#   'adChange': 0.05,
#   'pctChange': 0.1618},
#  {'code': 'VND',
#   'date': '2022-03-29',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 30.2,
#   'ceilingPrice': 32.3,
#   'floorPrice': 28.1,
#   'open': 30.9,
#   'high': 31.25,
#   'low': 30.5,
#   'close': 30.9,
#   'average': 30.87,
#   'adOpen': 30.9,
#   'adHigh': 31.25,
#   'adLow': 30.5,
#   'adClose': 30.9,
#   'adAverage': 30.87,
#   'nmVolume': 5304000.0,
#   'nmValue': 163730465000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.7,
#   'adChange': 0.7,
#   'pctChange': 2.3179},
#  {'code': 'VND',
#   'date': '2022-03-28',
#   'time': '15:03:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 31.1,
#   'ceilingPrice': 33.25,
#   'floorPrice': 28.95,
#   'open': 30.6,
#   'high': 31.0,
#   'low': 29.8,
#   'close': 30.2,
#   'average': 30.38,
#   'adOpen': 30.6,
#   'adHigh': 31.0,
#   'adLow': 29.8,
#   'adClose': 30.2,
#   'adAverage': 30.38,
#   'nmVolume': 10102500.0,
#   'nmValue': 306922900000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.9,
#   'adChange': -0.9,
#   'pctChange': -2.8939},
#  {'code': 'VND',
#   'date': '2022-03-25',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 31.5,
#   'ceilingPrice': 33.7,
#   'floorPrice': 29.3,
#   'open': 31.3,
#   'high': 31.8,
#   'low': 31.0,
#   'close': 31.1,
#   'average': 31.25,
#   'adOpen': 31.3,
#   'adHigh': 31.8,
#   'adLow': 31.0,
#   'adClose': 31.1,
#   'adAverage': 31.25,
#   'nmVolume': 8458900.0,
#   'nmValue': 264348125000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.4,
#   'adChange': -0.4,
#   'pctChange': -1.2698},
#  {'code': 'VND',
#   'date': '2022-03-24',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 31.95,
#   'ceilingPrice': 34.15,
#   'floorPrice': 29.75,
#   'open': 31.95,
#   'high': 32.0,
#   'low': 31.5,
#   'close': 31.5,
#   'average': 31.72,
#   'adOpen': 31.95,
#   'adHigh': 32.0,
#   'adLow': 31.5,
#   'adClose': 31.5,
#   'adAverage': 31.72,
#   'nmVolume': 8935200.0,
#   'nmValue': 283420135000.0,
#   'ptVolume': 1113500.0,
#   'ptValue': 33293650000.0,
#   'change': -0.45,
#   'adChange': -0.45,
#   'pctChange': -1.4085},
#  {'code': 'VND',
#   'date': '2022-03-23',
#   'time': '15:03:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 32.15,
#   'ceilingPrice': 34.4,
#   'floorPrice': 29.9,
#   'open': 32.2,
#   'high': 32.5,
#   'low': 31.85,
#   'close': 31.95,
#   'average': 32.17,
#   'adOpen': 32.2,
#   'adHigh': 32.5,
#   'adLow': 31.85,
#   'adClose': 31.95,
#   'adAverage': 32.17,
#   'nmVolume': 6824800.0,
#   'nmValue': 219542345000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.2,
#   'adChange': -0.2,
#   'pctChange': -0.6221},
#  {'code': 'VND',
#   'date': '2022-03-22',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 32.0,
#   'ceilingPrice': 34.2,
#   'floorPrice': 29.8,
#   'open': 32.0,
#   'high': 32.9,
#   'low': 31.95,
#   'close': 32.15,
#   'average': 32.33,
#   'adOpen': 32.0,
#   'adHigh': 32.9,
#   'adLow': 31.95,
#   'adClose': 32.15,
#   'adAverage': 32.33,
#   'nmVolume': 8155200.0,
#   'nmValue': 263642885000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.15,
#   'adChange': 0.15,
#   'pctChange': 0.4688},
#  {'code': 'VND',
#   'date': '2022-03-21',
#   'time': '15:03:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 31.95,
#   'ceilingPrice': 34.15,
#   'floorPrice': 29.75,
#   'open': 32.05,
#   'high': 32.3,
#   'low': 31.7,
#   'close': 32.0,
#   'average': 31.9,
#   'adOpen': 32.05,
#   'adHigh': 32.3,
#   'adLow': 31.7,
#   'adClose': 32.0,
#   'adAverage': 31.9,
#   'nmVolume': 6935100.0,
#   'nmValue': 221253185000.0,
#   'ptVolume': 100000.0,
#   'ptValue': 3000000000.0,
#   'change': 0.05,
#   'adChange': 0.05,
#   'pctChange': 0.1565},
#  {'code': 'VND',
#   'date': '2022-03-18',
#   'time': '15:03:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 32.1,
#   'ceilingPrice': 34.3,
#   'floorPrice': 29.9,
#   'open': 32.0,
#   'high': 32.4,
#   'low': 31.7,
#   'close': 31.95,
#   'average': 31.97,
#   'adOpen': 32.0,
#   'adHigh': 32.4,
#   'adLow': 31.7,
#   'adClose': 31.95,
#   'adAverage': 31.97,
#   'nmVolume': 13105600.0,
#   'nmValue': 419033420000.0,
#   'ptVolume': 1000000.0,
#   'ptValue': 29900000000.0,
#   'change': -0.15,
#   'adChange': -0.15,
#   'pctChange': -0.4673},
#  {'code': 'VND',
#   'date': '2022-03-17',
#   'time': '15:03:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 32.55,
#   'ceilingPrice': 34.8,
#   'floorPrice': 30.3,
#   'open': 33.0,
#   'high': 33.0,
#   'low': 32.0,
#   'close': 32.1,
#   'average': 32.36,
#   'adOpen': 33.0,
#   'adHigh': 33.0,
#   'adLow': 32.0,
#   'adClose': 32.1,
#   'adAverage': 32.36,
#   'nmVolume': 6099500.0,
#   'nmValue': 197362225000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.45,
#   'adChange': -0.45,
#   'pctChange': -1.3825},
#  {'code': 'VND',
#   'date': '2022-03-16',
#   'time': '15:03:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 32.6,
#   'ceilingPrice': 34.85,
#   'floorPrice': 30.35,
#   'open': 33.2,
#   'high': 33.2,
#   'low': 32.45,
#   'close': 32.55,
#   'average': 32.75,
#   'adOpen': 33.2,
#   'adHigh': 33.2,
#   'adLow': 32.45,
#   'adClose': 32.55,
#   'adAverage': 32.75,
#   'nmVolume': 4868500.0,
#   'nmValue': 159455775000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.05,
#   'adChange': -0.05,
#   'pctChange': -0.1534},
#  {'code': 'VND',
#   'date': '2022-03-15',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 31.75,
#   'ceilingPrice': 33.95,
#   'floorPrice': 29.55,
#   'open': 31.9,
#   'high': 33.55,
#   'low': 31.75,
#   'close': 32.6,
#   'average': 32.64,
#   'adOpen': 31.9,
#   'adHigh': 33.55,
#   'adLow': 31.75,
#   'adClose': 32.6,
#   'adAverage': 32.64,
#   'nmVolume': 8550700.0,
#   'nmValue': 279070635000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.85,
#   'adChange': 0.85,
#   'pctChange': 2.6772},
#  {'code': 'VND',
#   'date': '2022-03-14',
#   'time': '15:03:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 32.5,
#   'ceilingPrice': 34.75,
#   'floorPrice': 30.25,
#   'open': 32.1,
#   'high': 32.35,
#   'low': 31.35,
#   'close': 31.75,
#   'average': 31.85,
#   'adOpen': 32.1,
#   'adHigh': 32.35,
#   'adLow': 31.35,
#   'adClose': 31.75,
#   'adAverage': 31.85,
#   'nmVolume': 7352000.0,
#   'nmValue': 234186755000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.75,
#   'adChange': -0.75,
#   'pctChange': -2.3077},
#  {'code': 'VND',
#   'date': '2022-03-11',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 31.85,
#   'ceilingPrice': 34.05,
#   'floorPrice': 29.65,
#   'open': 34.05,
#   'high': 34.05,
#   'low': 32.5,
#   'close': 32.5,
#   'average': 33.54,
#   'adOpen': 34.05,
#   'adHigh': 34.05,
#   'adLow': 32.5,
#   'adClose': 32.5,
#   'adAverage': 33.54,
#   'nmVolume': 32597700.0,
#   'nmValue': 1093253040000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.65,
#   'adChange': 0.65,
#   'pctChange': 2.0408},
#  {'code': 'VND',
#   'date': '2022-03-10',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 29.85,
#   'ceilingPrice': 31.85,
#   'floorPrice': 27.75,
#   'open': 31.85,
#   'high': 31.85,
#   'low': 31.85,
#   'close': 31.85,
#   'average': 31.85,
#   'adOpen': 31.85,
#   'adHigh': 31.85,
#   'adLow': 31.85,
#   'adClose': 31.85,
#   'adAverage': 31.85,
#   'nmVolume': 2000300.0,
#   'nmValue': 63709555000.0,
#   'ptVolume': 1291800.0,
#   'ptValue': 38740400000.0,
#   'change': 2.0,
#   'adChange': 2.0,
#   'pctChange': 6.7002},
#  {'code': 'VND',
#   'date': '2022-03-09',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 75.0,
#   'ceilingPrice': 80.2,
#   'floorPrice': 69.8,
#   'open': 75.4,
#   'high': 75.7,
#   'low': 73.5,
#   'close': 73.5,
#   'average': 74.23,
#   'adOpen': 30.622,
#   'adHigh': 30.743,
#   'adLow': 29.85,
#   'adClose': 29.85,
#   'adAverage': 30.146,
#   'nmVolume': 11808600.0,
#   'nmValue': 876556520000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.5,
#   'adChange': -0.6092,
#   'pctChange': -2.0},
#  {'code': 'VND',
#   'date': '2022-03-08',
#   'time': '15:03:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 76.1,
#   'ceilingPrice': 81.4,
#   'floorPrice': 70.8,
#   'open': 75.2,
#   'high': 77.0,
#   'low': 75.0,
#   'close': 75.0,
#   'average': 75.96,
#   'adOpen': 30.54,
#   'adHigh': 31.271,
#   'adLow': 30.459,
#   'adClose': 30.459,
#   'adAverage': 30.849,
#   'nmVolume': 7236800.0,
#   'nmValue': 549742520000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.1,
#   'adChange': -0.4467,
#   'pctChange': -1.4455},
#  {'code': 'VND',
#   'date': '2022-03-07',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 77.0,
#   'ceilingPrice': 82.3,
#   'floorPrice': 71.7,
#   'open': 76.3,
#   'high': 77.5,
#   'low': 76.0,
#   'close': 76.1,
#   'average': 76.5,
#   'adOpen': 30.987,
#   'adHigh': 31.474,
#   'adLow': 30.865,
#   'adClose': 30.906,
#   'adAverage': 31.068,
#   'nmVolume': 6682900.0,
#   'nmValue': 511271010000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.9,
#   'adChange': -0.3655,
#   'pctChange': -1.1688},
#  {'code': 'VND',
#   'date': '2022-03-04',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 76.8,
#   'ceilingPrice': 82.1,
#   'floorPrice': 71.5,
#   'open': 77.5,
#   'high': 78.9,
#   'low': 77.0,
#   'close': 77.0,
#   'average': 77.88,
#   'adOpen': 31.474,
#   'adHigh': 32.043,
#   'adLow': 31.271,
#   'adClose': 31.271,
#   'adAverage': 31.629,
#   'nmVolume': 4592100.0,
#   'nmValue': 357617180000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.2,
#   'adChange': 0.0812,
#   'pctChange': 0.2604},
#  {'code': 'VND',
#   'date': '2022-03-03',
#   'time': '15:03:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 75.9,
#   'ceilingPrice': 81.2,
#   'floorPrice': 70.6,
#   'open': 76.3,
#   'high': 76.9,
#   'low': 75.1,
#   'close': 76.8,
#   'average': 75.91,
#   'adOpen': 30.987,
#   'adHigh': 31.231,
#   'adLow': 30.5,
#   'adClose': 31.19,
#   'adAverage': 30.829,
#   'nmVolume': 4220200.0,
#   'nmValue': 320335070000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.9,
#   'adChange': 0.3655,
#   'pctChange': 1.1858},
#  {'code': 'VND',
#   'date': '2022-03-02',
#   'time': '15:03:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 78.5,
#   'ceilingPrice': 83.9,
#   'floorPrice': 73.1,
#   'open': 77.6,
#   'high': 78.3,
#   'low': 75.5,
#   'close': 75.9,
#   'average': 76.59,
#   'adOpen': 31.515,
#   'adHigh': 31.799,
#   'adLow': 30.662,
#   'adClose': 30.825,
#   'adAverage': 31.105,
#   'nmVolume': 10093200.0,
#   'nmValue': 772995820000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -2.6,
#   'adChange': -1.0559,
#   'pctChange': -3.3121},
#  {'code': 'VND',
#   'date': '2022-03-01',
#   'time': '15:03:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 78.8,
#   'ceilingPrice': 84.3,
#   'floorPrice': 73.3,
#   'open': 79.2,
#   'high': 79.7,
#   'low': 77.8,
#   'close': 78.5,
#   'average': 78.51,
#   'adOpen': 32.165,
#   'adHigh': 32.368,
#   'adLow': 31.596,
#   'adClose': 31.881,
#   'adAverage': 31.885,
#   'nmVolume': 6539700.0,
#   'nmValue': 513415340000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.3,
#   'adChange': -0.1218,
#   'pctChange': -0.3807},
#  {'code': 'VND',
#   'date': '2022-02-28',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 78.1,
#   'ceilingPrice': 83.5,
#   'floorPrice': 72.7,
#   'open': 79.5,
#   'high': 80.3,
#   'low': 77.9,
#   'close': 78.8,
#   'average': 78.97,
#   'adOpen': 32.287,
#   'adHigh': 32.612,
#   'adLow': 31.637,
#   'adClose': 32.002,
#   'adAverage': 32.071,
#   'nmVolume': 5989600.0,
#   'nmValue': 472993120000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.7,
#   'adChange': 0.2843,
#   'pctChange': 0.8963},
#  {'code': 'VND',
#   'date': '2022-02-25',
#   'time': '15:02:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 76.0,
#   'ceilingPrice': 81.3,
#   'floorPrice': 70.7,
#   'open': 77.0,
#   'high': 81.0,
#   'low': 76.6,
#   'close': 78.1,
#   'average': 78.88,
#   'adOpen': 31.271,
#   'adHigh': 32.896,
#   'adLow': 31.109,
#   'adClose': 31.718,
#   'adAverage': 32.035,
#   'nmVolume': 11134100.0,
#   'nmValue': 878288990000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 2.1,
#   'adChange': 0.8529,
#   'pctChange': 2.7632},
#  {'code': 'VND',
#   'date': '2022-02-24',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 74.4,
#   'ceilingPrice': 79.6,
#   'floorPrice': 69.2,
#   'open': 74.1,
#   'high': 77.4,
#   'low': 72.0,
#   'close': 76.0,
#   'average': 75.44,
#   'adOpen': 30.094,
#   'adHigh': 31.434,
#   'adLow': 29.241,
#   'adClose': 30.865,
#   'adAverage': 30.638,
#   'nmVolume': 9603700.0,
#   'nmValue': 724507920000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.6,
#   'adChange': 0.6498,
#   'pctChange': 2.1505},
#  {'code': 'VND',
#   'date': '2022-02-23',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 73.5,
#   'ceilingPrice': 78.6,
#   'floorPrice': 68.4,
#   'open': 74.1,
#   'high': 74.9,
#   'low': 73.8,
#   'close': 74.4,
#   'average': 74.32,
#   'adOpen': 30.094,
#   'adHigh': 30.419,
#   'adLow': 29.972,
#   'adClose': 30.215,
#   'adAverage': 30.183,
#   'nmVolume': 2332300.0,
#   'nmValue': 173327860000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.9,
#   'adChange': 0.3655,
#   'pctChange': 1.2245},
#  {'code': 'VND',
#   'date': '2022-02-22',
#   'time': '15:02:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 75.1,
#   'ceilingPrice': 80.3,
#   'floorPrice': 69.9,
#   'open': 73.7,
#   'high': 74.8,
#   'low': 72.5,
#   'close': 73.5,
#   'average': 73.61,
#   'adOpen': 29.931,
#   'adHigh': 30.378,
#   'adLow': 29.444,
#   'adClose': 29.85,
#   'adAverage': 29.895,
#   'nmVolume': 4542100.0,
#   'nmValue': 334325780000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.6,
#   'adChange': -0.6498,
#   'pctChange': -2.1305},
#  {'code': 'VND',
#   'date': '2022-02-21',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 72.1,
#   'ceilingPrice': 77.1,
#   'floorPrice': 67.1,
#   'open': 72.6,
#   'high': 76.0,
#   'low': 72.5,
#   'close': 75.1,
#   'average': 74.79,
#   'adOpen': 29.484,
#   'adHigh': 30.865,
#   'adLow': 29.444,
#   'adClose': 30.5,
#   'adAverage': 30.374,
#   'nmVolume': 5775200.0,
#   'nmValue': 431940910000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 3.0,
#   'adChange': 1.2184,
#   'pctChange': 4.1609},
#  {'code': 'VND',
#   'date': '2022-02-18',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 71.1,
#   'ceilingPrice': 76.0,
#   'floorPrice': 66.2,
#   'open': 70.1,
#   'high': 72.9,
#   'low': 69.8,
#   'close': 72.1,
#   'average': 71.54,
#   'adOpen': 28.469,
#   'adHigh': 29.606,
#   'adLow': 28.347,
#   'adClose': 29.281,
#   'adAverage': 29.054,
#   'nmVolume': 4821000.0,
#   'nmValue': 344879400000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.0,
#   'adChange': 0.4061,
#   'pctChange': 1.4065},
#  {'code': 'VND',
#   'date': '2022-02-17',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 71.5,
#   'ceilingPrice': 76.5,
#   'floorPrice': 66.5,
#   'open': 71.5,
#   'high': 71.9,
#   'low': 70.7,
#   'close': 71.1,
#   'average': 71.45,
#   'adOpen': 29.038,
#   'adHigh': 29.2,
#   'adLow': 28.713,
#   'adClose': 28.875,
#   'adAverage': 29.017,
#   'nmVolume': 2532600.0,
#   'nmValue': 180945410000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.4,
#   'adChange': -0.1624,
#   'pctChange': -0.5594},
#  {'code': 'VND',
#   'date': '2022-02-16',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 70.3,
#   'ceilingPrice': 75.2,
#   'floorPrice': 65.4,
#   'open': 71.0,
#   'high': 73.0,
#   'low': 70.5,
#   'close': 71.5,
#   'average': 71.76,
#   'adOpen': 28.835,
#   'adHigh': 29.647,
#   'adLow': 28.632,
#   'adClose': 29.038,
#   'adAverage': 29.143,
#   'nmVolume': 2751100.0,
#   'nmValue': 197423460000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.2,
#   'adChange': 0.4874,
#   'pctChange': 1.707},
#  {'code': 'VND',
#   'date': '2022-02-15',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 68.0,
#   'ceilingPrice': 72.7,
#   'floorPrice': 63.3,
#   'open': 69.0,
#   'high': 70.6,
#   'low': 67.5,
#   'close': 70.3,
#   'average': 69.13,
#   'adOpen': 28.022,
#   'adHigh': 28.672,
#   'adLow': 27.413,
#   'adClose': 28.55,
#   'adAverage': 28.075,
#   'nmVolume': 4099300.0,
#   'nmValue': 283398100000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 2.3,
#   'adChange': 0.9341,
#   'pctChange': 3.3824},
#  {'code': 'VND',
#   'date': '2022-02-14',
#   'time': '15:02:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 71.5,
#   'ceilingPrice': 76.5,
#   'floorPrice': 66.5,
#   'open': 69.7,
#   'high': 71.0,
#   'low': 68.0,
#   'close': 68.0,
#   'average': 69.84,
#   'adOpen': 28.307,
#   'adHigh': 28.835,
#   'adLow': 27.616,
#   'adClose': 27.616,
#   'adAverage': 28.364,
#   'nmVolume': 4523800.0,
#   'nmValue': 315963110000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -3.5,
#   'adChange': -1.4214,
#   'pctChange': -4.8951},
#  {'code': 'VND',
#   'date': '2022-02-11',
#   'time': '15:02:05',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 71.0,
#   'ceilingPrice': 75.9,
#   'floorPrice': 66.1,
#   'open': 70.6,
#   'high': 72.2,
#   'low': 70.2,
#   'close': 71.5,
#   'average': 71.28,
#   'adOpen': 28.672,
#   'adHigh': 29.322,
#   'adLow': 28.51,
#   'adClose': 29.038,
#   'adAverage': 28.948,
#   'nmVolume': 3188400.0,
#   'nmValue': 227266410000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.5,
#   'adChange': 0.2031,
#   'pctChange': 0.7042},
#  {'code': 'VND',
#   'date': '2022-02-10',
#   'time': '15:02:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 72.0,
#   'ceilingPrice': 77.0,
#   'floorPrice': 67.0,
#   'open': 71.9,
#   'high': 72.7,
#   'low': 70.1,
#   'close': 71.0,
#   'average': 71.56,
#   'adOpen': 29.2,
#   'adHigh': 29.525,
#   'adLow': 28.469,
#   'adClose': 28.835,
#   'adAverage': 29.062,
#   'nmVolume': 2717400.0,
#   'nmValue': 194460730000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.0,
#   'adChange': -0.4061,
#   'pctChange': -1.3889},
#  {'code': 'VND',
#   'date': '2022-02-09',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 70.0,
#   'ceilingPrice': 74.9,
#   'floorPrice': 65.1,
#   'open': 70.0,
#   'high': 72.9,
#   'low': 69.5,
#   'close': 72.0,
#   'average': 71.54,
#   'adOpen': 28.429,
#   'adHigh': 29.606,
#   'adLow': 28.225,
#   'adClose': 29.241,
#   'adAverage': 29.054,
#   'nmVolume': 5053900.0,
#   'nmValue': 361556950000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 2.0,
#   'adChange': 0.8123,
#   'pctChange': 2.8571},
#  {'code': 'VND',
#   'date': '2022-02-08',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 70.4,
#   'ceilingPrice': 75.3,
#   'floorPrice': 65.5,
#   'open': 70.5,
#   'high': 70.5,
#   'low': 68.2,
#   'close': 70.0,
#   'average': 69.73,
#   'adOpen': 28.632,
#   'adHigh': 28.632,
#   'adLow': 27.698,
#   'adClose': 28.429,
#   'adAverage': 28.319,
#   'nmVolume': 2728600.0,
#   'nmValue': 190275240000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.4,
#   'adChange': -0.1625,
#   'pctChange': -0.5682},
#  {'code': 'VND',
#   'date': '2022-02-07',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 69.0,
#   'ceilingPrice': 73.8,
#   'floorPrice': 64.2,
#   'open': 69.8,
#   'high': 71.8,
#   'low': 69.2,
#   'close': 70.4,
#   'average': 70.76,
#   'adOpen': 28.347,
#   'adHigh': 29.16,
#   'adLow': 28.104,
#   'adClose': 28.591,
#   'adAverage': 28.737,
#   'nmVolume': 4058400.0,
#   'nmValue': 287184730000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.4,
#   'adChange': 0.5686,
#   'pctChange': 2.029},
#  {'code': 'VND',
#   'date': '2022-01-28',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 65.0,
#   'ceilingPrice': 69.5,
#   'floorPrice': 60.5,
#   'open': 65.0,
#   'high': 69.0,
#   'low': 64.8,
#   'close': 69.0,
#   'average': 67.17,
#   'adOpen': 26.398,
#   'adHigh': 28.022,
#   'adLow': 26.317,
#   'adClose': 28.022,
#   'adAverage': 27.279,
#   'nmVolume': 4715200.0,
#   'nmValue': 316701900000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 4.0,
#   'adChange': 1.6245,
#   'pctChange': 6.1538},
#  {'code': 'VND',
#   'date': '2022-01-27',
#   'time': '15:01:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 62.9,
#   'ceilingPrice': 67.3,
#   'floorPrice': 58.5,
#   'open': 62.4,
#   'high': 66.8,
#   'low': 62.1,
#   'close': 65.0,
#   'average': 64.81,
#   'adOpen': 25.342,
#   'adHigh': 27.129,
#   'adLow': 25.22,
#   'adClose': 26.398,
#   'adAverage': 26.321,
#   'nmVolume': 4314900.0,
#   'nmValue': 279645190000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 2.1,
#   'adChange': 0.8529,
#   'pctChange': 3.3386},
#  {'code': 'VND',
#   'date': '2022-01-26',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 62.7,
#   'ceilingPrice': 67.0,
#   'floorPrice': 58.4,
#   'open': 63.0,
#   'high': 64.4,
#   'low': 61.5,
#   'close': 62.9,
#   'average': 63.13,
#   'adOpen': 25.586,
#   'adHigh': 26.154,
#   'adLow': 24.977,
#   'adClose': 25.545,
#   'adAverage': 25.638,
#   'nmVolume': 4556200.0,
#   'nmValue': 287625510000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.2,
#   'adChange': 0.0812,
#   'pctChange': 0.319},
#  {'code': 'VND',
#   'date': '2022-01-25',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 61.2,
#   'ceilingPrice': 65.4,
#   'floorPrice': 57.0,
#   'open': 60.6,
#   'high': 63.0,
#   'low': 59.1,
#   'close': 62.7,
#   'average': 61.4,
#   'adOpen': 24.611,
#   'adHigh': 25.586,
#   'adLow': 24.002,
#   'adClose': 25.464,
#   'adAverage': 24.936,
#   'nmVolume': 4062100.0,
#   'nmValue': 249418460000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.5,
#   'adChange': 0.6092,
#   'pctChange': 2.451},
#  {'code': 'VND',
#   'date': '2022-01-24',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 65.8,
#   'ceilingPrice': 70.4,
#   'floorPrice': 61.2,
#   'open': 63.9,
#   'high': 64.8,
#   'low': 61.2,
#   'close': 61.2,
#   'average': 61.79,
#   'adOpen': 25.951,
#   'adHigh': 26.317,
#   'adLow': 24.855,
#   'adClose': 24.855,
#   'adAverage': 25.094,
#   'nmVolume': 10824100.0,
#   'nmValue': 668796400000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -4.6,
#   'adChange': -1.8682,
#   'pctChange': -6.9909},
#  {'code': 'VND',
#   'date': '2022-01-21',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 67.8,
#   'ceilingPrice': 72.5,
#   'floorPrice': 63.1,
#   'open': 67.7,
#   'high': 67.7,
#   'low': 65.7,
#   'close': 65.8,
#   'average': 66.67,
#   'adOpen': 27.494,
#   'adHigh': 27.494,
#   'adLow': 26.682,
#   'adClose': 26.723,
#   'adAverage': 27.076,
#   'nmVolume': 3340700.0,
#   'nmValue': 222709820000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -2.0,
#   'adChange': -0.8122,
#   'pctChange': -2.9499},
#  {'code': 'VND',
#   'date': '2022-01-20',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 66.7,
#   'ceilingPrice': 71.3,
#   'floorPrice': 62.1,
#   'open': 67.0,
#   'high': 69.5,
#   'low': 64.8,
#   'close': 67.8,
#   'average': 66.82,
#   'adOpen': 27.21,
#   'adHigh': 28.225,
#   'adLow': 26.317,
#   'adClose': 27.535,
#   'adAverage': 27.137,
#   'nmVolume': 5270900.0,
#   'nmValue': 352191410000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.1,
#   'adChange': 0.4467,
#   'pctChange': 1.6492},
#  {'code': 'VND',
#   'date': '2022-01-19',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 62.4,
#   'ceilingPrice': 66.7,
#   'floorPrice': 58.1,
#   'open': 64.5,
#   'high': 66.7,
#   'low': 63.7,
#   'close': 66.7,
#   'average': 64.72,
#   'adOpen': 26.195,
#   'adHigh': 27.088,
#   'adLow': 25.87,
#   'adClose': 27.088,
#   'adAverage': 26.284,
#   'nmVolume': 5719000.0,
#   'nmValue': 370147480000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 4.3,
#   'adChange': 1.7463,
#   'pctChange': 6.891},
#  {'code': 'VND',
#   'date': '2022-01-18',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 67.0,
#   'ceilingPrice': 71.6,
#   'floorPrice': 62.4,
#   'open': 65.1,
#   'high': 66.0,
#   'low': 62.4,
#   'close': 62.4,
#   'average': 63.74,
#   'adOpen': 26.439,
#   'adHigh': 26.804,
#   'adLow': 25.342,
#   'adClose': 25.342,
#   'adAverage': 25.886,
#   'nmVolume': 10178000.0,
#   'nmValue': 648783740000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -4.6,
#   'adChange': -1.8682,
#   'pctChange': -6.8657},
#  {'code': 'VND',
#   'date': '2022-01-17',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 72.0,
#   'ceilingPrice': 77.0,
#   'floorPrice': 67.0,
#   'open': 72.0,
#   'high': 72.4,
#   'low': 67.0,
#   'close': 67.0,
#   'average': 68.02,
#   'adOpen': 29.241,
#   'adHigh': 29.403,
#   'adLow': 27.21,
#   'adClose': 27.21,
#   'adAverage': 27.624,
#   'nmVolume': 15771000.0,
#   'nmValue': 1072816270000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -5.0,
#   'adChange': -2.0306,
#   'pctChange': -6.9444},
#  {'code': 'VND',
#   'date': '2022-01-14',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 72.9,
#   'ceilingPrice': 78.0,
#   'floorPrice': 67.8,
#   'open': 72.0,
#   'high': 73.8,
#   'low': 72.0,
#   'close': 72.0,
#   'average': 72.81,
#   'adOpen': 29.241,
#   'adHigh': 29.972,
#   'adLow': 29.241,
#   'adClose': 29.241,
#   'adAverage': 29.57,
#   'nmVolume': 3774600.0,
#   'nmValue': 274838970000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.9,
#   'adChange': -0.3655,
#   'pctChange': -1.2346},
#  {'code': 'VND',
#   'date': '2022-01-13',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 76.4,
#   'ceilingPrice': 81.7,
#   'floorPrice': 71.1,
#   'open': 76.9,
#   'high': 77.4,
#   'low': 72.2,
#   'close': 72.9,
#   'average': 74.01,
#   'adOpen': 31.231,
#   'adHigh': 31.434,
#   'adLow': 29.322,
#   'adClose': 29.606,
#   'adAverage': 30.057,
#   'nmVolume': 5859200.0,
#   'nmValue': 433653570000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -3.5,
#   'adChange': -1.4214,
#   'pctChange': -4.5812},
#  {'code': 'VND',
#   'date': '2022-01-12',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 73.0,
#   'ceilingPrice': 78.1,
#   'floorPrice': 67.9,
#   'open': 72.5,
#   'high': 76.7,
#   'low': 72.0,
#   'close': 76.4,
#   'average': 74.27,
#   'adOpen': 29.444,
#   'adHigh': 31.15,
#   'adLow': 29.241,
#   'adClose': 31.028,
#   'adAverage': 30.163,
#   'nmVolume': 7979000.0,
#   'nmValue': 592589940000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 3.4,
#   'adChange': 1.3808,
#   'pctChange': 4.6575},
#  {'code': 'VND',
#   'date': '2022-01-11',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 77.2,
#   'ceilingPrice': 82.6,
#   'floorPrice': 71.8,
#   'open': 79.0,
#   'high': 79.0,
#   'low': 73.0,
#   'close': 73.0,
#   'average': 75.37,
#   'adOpen': 32.084,
#   'adHigh': 32.084,
#   'adLow': 29.647,
#   'adClose': 29.647,
#   'adAverage': 30.609,
#   'nmVolume': 9943500.0,
#   'nmValue': 749484490000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -4.2,
#   'adChange': -1.7057,
#   'pctChange': -5.4404},
#  {'code': 'VND',
#   'date': '2022-01-10',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 80.0,
#   'ceilingPrice': 85.6,
#   'floorPrice': 74.4,
#   'open': 79.5,
#   'high': 80.6,
#   'low': 77.2,
#   'close': 77.2,
#   'average': 78.23,
#   'adOpen': 32.287,
#   'adHigh': 32.733,
#   'adLow': 31.353,
#   'adClose': 31.353,
#   'adAverage': 31.771,
#   'nmVolume': 11309600.0,
#   'nmValue': 884694600000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -2.8,
#   'adChange': -1.1372,
#   'pctChange': -3.5},
#  {'code': 'VND',
#   'date': '2022-01-07',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 81.2,
#   'ceilingPrice': 86.8,
#   'floorPrice': 75.6,
#   'open': 80.5,
#   'high': 81.7,
#   'low': 79.7,
#   'close': 80.0,
#   'average': 80.47,
#   'adOpen': 32.693,
#   'adHigh': 33.18,
#   'adLow': 32.368,
#   'adClose': 32.49,
#   'adAverage': 32.681,
#   'nmVolume': 6086000.0,
#   'nmValue': 489739400000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.2,
#   'adChange': -0.4874,
#   'pctChange': -1.4778},
#  {'code': 'VND',
#   'date': '2022-01-06',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 82.1,
#   'ceilingPrice': 87.8,
#   'floorPrice': 76.4,
#   'open': 81.8,
#   'high': 83.1,
#   'low': 81.0,
#   'close': 81.2,
#   'average': 81.62,
#   'adOpen': 33.221,
#   'adHigh': 33.749,
#   'adLow': 32.896,
#   'adClose': 32.977,
#   'adAverage': 33.148,
#   'nmVolume': 5635300.0,
#   'nmValue': 459956480000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.9,
#   'adChange': -0.3655,
#   'pctChange': -1.0962},
#  {'code': 'VND',
#   'date': '2022-01-05',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 83.0,
#   'ceilingPrice': 88.8,
#   'floorPrice': 77.2,
#   'open': 83.0,
#   'high': 84.8,
#   'low': 82.1,
#   'close': 82.1,
#   'average': 83.29,
#   'adOpen': 33.708,
#   'adHigh': 34.439,
#   'adLow': 33.343,
#   'adClose': 33.343,
#   'adAverage': 33.826,
#   'nmVolume': 6570000.0,
#   'nmValue': 547220920000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.9,
#   'adChange': -0.3655,
#   'pctChange': -1.0843},
#  {'code': 'VND',
#   'date': '2022-01-04',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 82.0,
#   'ceilingPrice': 87.7,
#   'floorPrice': 76.3,
#   'open': 82.1,
#   'high': 84.4,
#   'low': 82.0,
#   'close': 83.0,
#   'average': 83.06,
#   'adOpen': 33.343,
#   'adHigh': 34.277,
#   'adLow': 33.302,
#   'adClose': 33.708,
#   'adAverage': 33.732,
#   'nmVolume': 5138300.0,
#   'nmValue': 426782450000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.0,
#   'adChange': 0.4061,
#   'pctChange': 1.2195},
#  {'code': 'VND',
#   'date': '2021-12-31',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 82.8,
#   'ceilingPrice': 88.5,
#   'floorPrice': 77.1,
#   'open': 83.8,
#   'high': 83.8,
#   'low': 81.4,
#   'close': 82.0,
#   'average': 82.31,
#   'adOpen': 34.033,
#   'adHigh': 34.033,
#   'adLow': 33.058,
#   'adClose': 33.302,
#   'adAverage': 33.428,
#   'nmVolume': 3670100.0,
#   'nmValue': 302102880000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.8,
#   'adChange': -0.3249,
#   'pctChange': -0.9662},
#  {'code': 'VND',
#   'date': '2021-12-30',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 79.0,
#   'ceilingPrice': 84.5,
#   'floorPrice': 73.5,
#   'open': 79.9,
#   'high': 83.0,
#   'low': 79.0,
#   'close': 82.8,
#   'average': 81.57,
#   'adOpen': 32.449,
#   'adHigh': 33.708,
#   'adLow': 32.084,
#   'adClose': 33.627,
#   'adAverage': 33.127,
#   'nmVolume': 7017200.0,
#   'nmValue': 572419570000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 3.8,
#   'adChange': 1.5433,
#   'pctChange': 4.8101},
#  {'code': 'VND',
#   'date': '2021-12-29',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 78.5,
#   'ceilingPrice': 83.9,
#   'floorPrice': 73.1,
#   'open': 78.3,
#   'high': 80.3,
#   'low': 77.2,
#   'close': 79.0,
#   'average': 78.88,
#   'adOpen': 31.799,
#   'adHigh': 32.612,
#   'adLow': 31.353,
#   'adClose': 32.084,
#   'adAverage': 32.035,
#   'nmVolume': 4658000.0,
#   'nmValue': 367408610000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.5,
#   'adChange': 0.2031,
#   'pctChange': 0.6369},
#  {'code': 'VND',
#   'date': '2021-12-28',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 80.0,
#   'ceilingPrice': 85.6,
#   'floorPrice': 74.4,
#   'open': 80.1,
#   'high': 81.2,
#   'low': 78.5,
#   'close': 78.5,
#   'average': 79.63,
#   'adOpen': 32.53,
#   'adHigh': 32.977,
#   'adLow': 31.881,
#   'adClose': 31.881,
#   'adAverage': 32.339,
#   'nmVolume': 5572100.0,
#   'nmValue': 443725090000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.5,
#   'adChange': -0.6092,
#   'pctChange': -1.875},
#  {'code': 'VND',
#   'date': '2021-12-27',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 79.9,
#   'ceilingPrice': 85.4,
#   'floorPrice': 74.4,
#   'open': 81.1,
#   'high': 82.4,
#   'low': 80.0,
#   'close': 80.0,
#   'average': 80.91,
#   'adOpen': 32.936,
#   'adHigh': 33.464,
#   'adLow': 32.49,
#   'adClose': 32.49,
#   'adAverage': 32.859,
#   'nmVolume': 3352200.0,
#   'nmValue': 271243030000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.1,
#   'adChange': 0.0406,
#   'pctChange': 0.1252},
#  {'code': 'VND',
#   'date': '2021-12-24',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 78.8,
#   'ceilingPrice': 84.3,
#   'floorPrice': 73.3,
#   'open': 79.0,
#   'high': 80.9,
#   'low': 77.0,
#   'close': 79.9,
#   'average': 78.95,
#   'adOpen': 32.084,
#   'adHigh': 32.855,
#   'adLow': 31.271,
#   'adClose': 32.449,
#   'adAverage': 32.063,
#   'nmVolume': 4563800.0,
#   'nmValue': 360305990000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.1,
#   'adChange': 0.4467,
#   'pctChange': 1.3959},
#  {'code': 'VND',
#   'date': '2021-12-23',
#   'time': '15:12:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 83.3,
#   'ceilingPrice': 89.1,
#   'floorPrice': 77.5,
#   'open': 82.5,
#   'high': 83.0,
#   'low': 78.0,
#   'close': 78.8,
#   'average': 80.22,
#   'adOpen': 33.505,
#   'adHigh': 33.708,
#   'adLow': 31.678,
#   'adClose': 32.002,
#   'adAverage': 32.579,
#   'nmVolume': 12384600.0,
#   'nmValue': 993487120000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -4.5,
#   'adChange': -1.8275,
#   'pctChange': -5.4022},
#  {'code': 'VND',
#   'date': '2021-12-22',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 84.8,
#   'ceilingPrice': 90.7,
#   'floorPrice': 78.9,
#   'open': 85.5,
#   'high': 85.5,
#   'low': 82.8,
#   'close': 83.3,
#   'average': 83.63,
#   'adOpen': 34.723,
#   'adHigh': 34.723,
#   'adLow': 33.627,
#   'adClose': 33.83,
#   'adAverage': 33.964,
#   'nmVolume': 7315400.0,
#   'nmValue': 611789180000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.5,
#   'adChange': -0.6092,
#   'pctChange': -1.7689},
#  {'code': 'VND',
#   'date': '2021-12-21',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 85.2,
#   'ceilingPrice': 91.1,
#   'floorPrice': 79.3,
#   'open': 85.6,
#   'high': 86.3,
#   'low': 84.2,
#   'close': 84.8,
#   'average': 85.3,
#   'adOpen': 34.764,
#   'adHigh': 35.048,
#   'adLow': 34.195,
#   'adClose': 34.439,
#   'adAverage': 34.642,
#   'nmVolume': 5790100.0,
#   'nmValue': 493883110000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.4,
#   'adChange': -0.1624,
#   'pctChange': -0.4695},
#  {'code': 'VND',
#   'date': '2021-12-20',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 80.0,
#   'ceilingPrice': 85.6,
#   'floorPrice': 74.4,
#   'open': 81.0,
#   'high': 85.5,
#   'low': 80.0,
#   'close': 85.2,
#   'average': 84.18,
#   'adOpen': 32.896,
#   'adHigh': 34.723,
#   'adLow': 32.49,
#   'adClose': 34.602,
#   'adAverage': 34.187,
#   'nmVolume': 10203200.0,
#   'nmValue': 858899260000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 5.2,
#   'adChange': 2.1119,
#   'pctChange': 6.5},
#  {'code': 'VND',
#   'date': '2021-12-17',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 77.0,
#   'ceilingPrice': 82.3,
#   'floorPrice': 71.7,
#   'open': 77.6,
#   'high': 80.0,
#   'low': 76.5,
#   'close': 80.0,
#   'average': 78.8,
#   'adOpen': 31.515,
#   'adHigh': 32.49,
#   'adLow': 31.068,
#   'adClose': 32.49,
#   'adAverage': 32.002,
#   'nmVolume': 9981000.0,
#   'nmValue': 786455530000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 3.0,
#   'adChange': 1.2184,
#   'pctChange': 3.8961},
#  {'code': 'VND',
#   'date': '2021-12-16',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 79.0,
#   'ceilingPrice': 84.5,
#   'floorPrice': 73.5,
#   'open': 79.1,
#   'high': 79.9,
#   'low': 76.4,
#   'close': 77.0,
#   'average': 77.57,
#   'adOpen': 32.124,
#   'adHigh': 32.449,
#   'adLow': 31.028,
#   'adClose': 31.271,
#   'adAverage': 31.503,
#   'nmVolume': 9606000.0,
#   'nmValue': 745105340000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -2.0,
#   'adChange': -0.8122,
#   'pctChange': -2.5316},
#  {'code': 'VND',
#   'date': '2021-12-15',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 80.7,
#   'ceilingPrice': 86.3,
#   'floorPrice': 75.1,
#   'open': 80.6,
#   'high': 81.2,
#   'low': 79.0,
#   'close': 79.0,
#   'average': 80.07,
#   'adOpen': 32.733,
#   'adHigh': 32.977,
#   'adLow': 32.084,
#   'adClose': 32.084,
#   'adAverage': 32.518,
#   'nmVolume': 4300800.0,
#   'nmValue': 344366640000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.7,
#   'adChange': -0.6904,
#   'pctChange': -2.1066},
#  {'code': 'VND',
#   'date': '2021-12-14',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 80.5,
#   'ceilingPrice': 86.1,
#   'floorPrice': 74.9,
#   'open': 80.9,
#   'high': 81.8,
#   'low': 79.2,
#   'close': 80.7,
#   'average': 80.87,
#   'adOpen': 32.855,
#   'adHigh': 33.221,
#   'adLow': 32.165,
#   'adClose': 32.774,
#   'adAverage': 32.843,
#   'nmVolume': 5137300.0,
#   'nmValue': 415441710000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.2,
#   'adChange': 0.0812,
#   'pctChange': 0.2484},
#  {'code': 'VND',
#   'date': '2021-12-13',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 79.0,
#   'ceilingPrice': 84.5,
#   'floorPrice': 73.5,
#   'open': 79.4,
#   'high': 81.0,
#   'low': 78.1,
#   'close': 80.5,
#   'average': 79.75,
#   'adOpen': 32.246,
#   'adHigh': 32.896,
#   'adLow': 31.718,
#   'adClose': 32.693,
#   'adAverage': 32.388,
#   'nmVolume': 6761000.0,
#   'nmValue': 539195020000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.5,
#   'adChange': 0.6092,
#   'pctChange': 1.8987},
#  {'code': 'VND',
#   'date': '2021-12-10',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 79.9,
#   'ceilingPrice': 85.4,
#   'floorPrice': 74.4,
#   'open': 79.5,
#   'high': 80.7,
#   'low': 78.0,
#   'close': 79.0,
#   'average': 79.22,
#   'adOpen': 32.287,
#   'adHigh': 32.774,
#   'adLow': 31.678,
#   'adClose': 32.084,
#   'adAverage': 32.173,
#   'nmVolume': 4585800.0,
#   'nmValue': 363277060000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.9,
#   'adChange': -0.3655,
#   'pctChange': -1.1264},
#  {'code': 'VND',
#   'date': '2021-12-09',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 75.9,
#   'ceilingPrice': 81.2,
#   'floorPrice': 70.6,
#   'open': 75.4,
#   'high': 79.9,
#   'low': 75.1,
#   'close': 79.9,
#   'average': 77.24,
#   'adOpen': 30.622,
#   'adHigh': 32.449,
#   'adLow': 30.5,
#   'adClose': 32.449,
#   'adAverage': 31.369,
#   'nmVolume': 5493000.0,
#   'nmValue': 424306050000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 4.0,
#   'adChange': 1.6245,
#   'pctChange': 5.2701},
#  {'code': 'VND',
#   'date': '2021-12-08',
#   'time': '15:12:01',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 74.7,
#   'ceilingPrice': 79.9,
#   'floorPrice': 69.5,
#   'open': 75.6,
#   'high': 76.5,
#   'low': 74.5,
#   'close': 75.9,
#   'average': 75.5,
#   'adOpen': 30.703,
#   'adHigh': 31.068,
#   'adLow': 30.256,
#   'adClose': 30.825,
#   'adAverage': 30.662,
#   'nmVolume': 4521100.0,
#   'nmValue': 341346540000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.2,
#   'adChange': 0.4874,
#   'pctChange': 1.6064},
#  {'code': 'VND',
#   'date': '2021-12-07',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 73.9,
#   'ceilingPrice': 79.0,
#   'floorPrice': 68.8,
#   'open': 75.4,
#   'high': 75.6,
#   'low': 73.1,
#   'close': 74.7,
#   'average': 74.27,
#   'adOpen': 30.622,
#   'adHigh': 30.703,
#   'adLow': 29.688,
#   'adClose': 30.337,
#   'adAverage': 30.163,
#   'nmVolume': 4965200.0,
#   'nmValue': 368744230000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.8,
#   'adChange': 0.3249,
#   'pctChange': 1.0825},
#  {'code': 'VND',
#   'date': '2021-12-06',
#   'time': '15:12:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 73.0,
#   'ceilingPrice': 78.1,
#   'floorPrice': 67.9,
#   'open': 74.0,
#   'high': 76.5,
#   'low': 72.1,
#   'close': 73.9,
#   'average': 74.08,
#   'adOpen': 30.053,
#   'adHigh': 31.068,
#   'adLow': 29.281,
#   'adClose': 30.012,
#   'adAverage': 30.086,
#   'nmVolume': 9022800.0,
#   'nmValue': 668367910000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.9,
#   'adChange': 0.3655,
#   'pctChange': 1.2329},
#  {'code': 'VND',
#   'date': '2021-12-03',
#   'time': '15:12:06',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 77.7,
#   'ceilingPrice': 83.1,
#   'floorPrice': 72.3,
#   'open': 78.4,
#   'high': 78.5,
#   'low': 73.0,
#   'close': 73.0,
#   'average': 76.06,
#   'adOpen': 31.84,
#   'adHigh': 31.881,
#   'adLow': 29.647,
#   'adClose': 29.647,
#   'adAverage': 30.89,
#   'nmVolume': 8460100.0,
#   'nmValue': 643443930000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -4.7,
#   'adChange': -1.9088,
#   'pctChange': -6.0489},
#  {'code': 'VND',
#   'date': '2021-12-02',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 78.0,
#   'ceilingPrice': 83.4,
#   'floorPrice': 72.6,
#   'open': 77.7,
#   'high': 79.5,
#   'low': 77.1,
#   'close': 77.7,
#   'average': 78.3,
#   'adOpen': 31.556,
#   'adHigh': 32.287,
#   'adLow': 31.312,
#   'adClose': 31.556,
#   'adAverage': 31.799,
#   'nmVolume': 3741200.0,
#   'nmValue': 292947240000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.3,
#   'adChange': -0.1218,
#   'pctChange': -0.3846},
#  {'code': 'VND',
#   'date': '2021-12-01',
#   'time': '15:12:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 79.0,
#   'ceilingPrice': 84.5,
#   'floorPrice': 73.5,
#   'open': 78.7,
#   'high': 79.0,
#   'low': 77.0,
#   'close': 78.0,
#   'average': 77.77,
#   'adOpen': 31.962,
#   'adHigh': 32.084,
#   'adLow': 31.271,
#   'adClose': 31.678,
#   'adAverage': 31.584,
#   'nmVolume': 7029100.0,
#   'nmValue': 546661850000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -1.0,
#   'adChange': -0.4061,
#   'pctChange': -1.2658},
#  {'code': 'VND',
#   'date': '2021-11-30',
#   'time': '15:11:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 79.9,
#   'ceilingPrice': 85.4,
#   'floorPrice': 74.4,
#   'open': 81.5,
#   'high': 81.6,
#   'low': 77.6,
#   'close': 79.0,
#   'average': 79.6,
#   'adOpen': 33.099,
#   'adHigh': 33.14,
#   'adLow': 31.515,
#   'adClose': 32.084,
#   'adAverage': 32.327,
#   'nmVolume': 8111500.0,
#   'nmValue': 645688910000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.9,
#   'adChange': -0.3655,
#   'pctChange': -1.1264},
#  {'code': 'VND',
#   'date': '2021-11-29',
#   'time': '15:11:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 78.0,
#   'ceilingPrice': 83.4,
#   'floorPrice': 72.6,
#   'open': 77.0,
#   'high': 80.5,
#   'low': 76.2,
#   'close': 79.9,
#   'average': 78.9,
#   'adOpen': 31.271,
#   'adHigh': 32.693,
#   'adLow': 30.946,
#   'adClose': 32.449,
#   'adAverage': 32.043,
#   'nmVolume': 5665100.0,
#   'nmValue': 446990220000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 1.9,
#   'adChange': 0.7716,
#   'pctChange': 2.4359},
#  {'code': 'VND',
#   'date': '2021-11-26',
#   'time': '15:11:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 81.1,
#   'ceilingPrice': 86.7,
#   'floorPrice': 75.5,
#   'open': 81.1,
#   'high': 81.5,
#   'low': 77.5,
#   'close': 78.0,
#   'average': 79.31,
#   'adOpen': 32.936,
#   'adHigh': 33.099,
#   'adLow': 31.474,
#   'adClose': 31.678,
#   'adAverage': 32.21,
#   'nmVolume': 13234400.0,
#   'nmValue': 1049588090000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -3.1,
#   'adChange': -1.259,
#   'pctChange': -3.8224},
#  {'code': 'VND',
#   'date': '2021-11-25',
#   'time': '15:11:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 81.4,
#   'ceilingPrice': 87.0,
#   'floorPrice': 75.8,
#   'open': 81.1,
#   'high': 82.9,
#   'low': 80.1,
#   'close': 81.1,
#   'average': 81.44,
#   'adOpen': 32.936,
#   'adHigh': 33.668,
#   'adLow': 32.53,
#   'adClose': 32.936,
#   'adAverage': 33.075,
#   'nmVolume': 5966500.0,
#   'nmValue': 485889810000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.3,
#   'adChange': -0.1218,
#   'pctChange': -0.3686},
#  {'code': 'VND',
#   'date': '2021-11-24',
#   'time': '15:11:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 80.7,
#   'ceilingPrice': 86.3,
#   'floorPrice': 75.1,
#   'open': 81.8,
#   'high': 82.7,
#   'low': 80.1,
#   'close': 81.4,
#   'average': 81.37,
#   'adOpen': 33.221,
#   'adHigh': 33.586,
#   'adLow': 32.53,
#   'adClose': 33.058,
#   'adAverage': 33.046,
#   'nmVolume': 6121900.0,
#   'nmValue': 498137300000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.7,
#   'adChange': 0.2843,
#   'pctChange': 0.8674},
#  {'code': 'VND',
#   'date': '2021-11-23',
#   'time': '15:11:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 75.5,
#   'ceilingPrice': 80.7,
#   'floorPrice': 70.3,
#   'open': 75.6,
#   'high': 80.7,
#   'low': 74.8,
#   'close': 80.7,
#   'average': 76.87,
#   'adOpen': 30.703,
#   'adHigh': 32.774,
#   'adLow': 30.378,
#   'adClose': 32.774,
#   'adAverage': 31.219,
#   'nmVolume': 7457900.0,
#   'nmValue': 573325090000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 5.2,
#   'adChange': 2.1118,
#   'pctChange': 6.8874},
#  {'code': 'VND',
#   'date': '2021-11-22',
#   'time': '15:11:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 75.0,
#   'ceilingPrice': 80.2,
#   'floorPrice': 69.8,
#   'open': 75.0,
#   'high': 77.5,
#   'low': 72.9,
#   'close': 75.5,
#   'average': 75.21,
#   'adOpen': 30.459,
#   'adHigh': 31.474,
#   'adLow': 29.606,
#   'adClose': 30.662,
#   'adAverage': 30.544,
#   'nmVolume': 9582400.0,
#   'nmValue': 720736860000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.5,
#   'adChange': 0.2031,
#   'pctChange': 0.6667},
#  {'code': 'VND',
#   'date': '2021-11-19',
#   'time': '15:11:05',
# ...
#   'floorPrice': 13.15,
#   'open': 13.9,
#   'high': 14.05,
#   'low': 13.8,
#   'close': 14.05,
#   'average': 13.93,
#   'adOpen': 3.357,
#   'adHigh': 3.393,
#   'adLow': 3.333,
#   'adClose': 3.393,
#   'adAverage': 3.364,
#   'nmVolume': 328310.0,
#   'nmValue': 4572255500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.05,
#   'adChange': -0.0121,
#   'pctChange': -0.3546},
#  {'code': 'VND',
#   'date': '2020-02-20',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.2,
#   'ceilingPrice': 15.15,
#   'floorPrice': 13.25,
#   'open': 14.0,
#   'high': 14.15,
#   'low': 13.85,
#   'close': 14.1,
#   'average': 13.98,
#   'adOpen': 3.381,
#   'adHigh': 3.417,
#   'adLow': 3.344,
#   'adClose': 3.405,
#   'adAverage': 3.376,
#   'nmVolume': 203430.0,
#   'nmValue': 2844062000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.1,
#   'adChange': -0.0241,
#   'pctChange': -0.7042},
#  {'code': 'VND',
#   'date': '2020-02-19',
#   'time': '15:02:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.2,
#   'ceilingPrice': 15.15,
#   'floorPrice': 13.25,
#   'open': 13.9,
#   'high': 14.2,
#   'low': 13.85,
#   'close': 14.2,
#   'average': 13.99,
#   'adOpen': 3.357,
#   'adHigh': 3.429,
#   'adLow': 3.344,
#   'adClose': 3.429,
#   'adAverage': 3.379,
#   'nmVolume': 258870.0,
#   'nmValue': 3621445000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.0,
#   'adChange': 0.0,
#   'pctChange': 0.0},
#  {'code': 'VND',
#   'date': '2020-02-18',
#   'time': '15:02:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.3,
#   'ceilingPrice': 15.3,
#   'floorPrice': 13.3,
#   'open': 14.3,
#   'high': 14.3,
#   'low': 13.8,
#   'close': 14.2,
#   'average': 14.02,
#   'adOpen': 3.453,
#   'adHigh': 3.453,
#   'adLow': 3.333,
#   'adClose': 3.429,
#   'adAverage': 3.386,
#   'nmVolume': 605060.0,
#   'nmValue': 8483761500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.1,
#   'adChange': -0.0241,
#   'pctChange': -0.6993},
#  {'code': 'VND',
#   'date': '2020-02-17',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.2,
#   'ceilingPrice': 15.15,
#   'floorPrice': 13.25,
#   'open': 14.2,
#   'high': 14.35,
#   'low': 14.0,
#   'close': 14.3,
#   'average': 14.15,
#   'adOpen': 3.429,
#   'adHigh': 3.465,
#   'adLow': 3.381,
#   'adClose': 3.453,
#   'adAverage': 3.417,
#   'nmVolume': 231090.0,
#   'nmValue': 3270920500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.1,
#   'adChange': 0.0241,
#   'pctChange': 0.7042},
#  {'code': 'VND',
#   'date': '2020-02-14',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.15,
#   'ceilingPrice': 15.1,
#   'floorPrice': 13.2,
#   'open': 14.15,
#   'high': 14.2,
#   'low': 13.9,
#   'close': 14.2,
#   'average': 14.02,
#   'adOpen': 3.417,
#   'adHigh': 3.429,
#   'adLow': 3.357,
#   'adClose': 3.429,
#   'adAverage': 3.386,
#   'nmVolume': 137900.0,
#   'nmValue': 1933597000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.05,
#   'adChange': 0.0121,
#   'pctChange': 0.3534},
#  {'code': 'VND',
#   'date': '2020-02-13',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.3,
#   'ceilingPrice': 15.3,
#   'floorPrice': 13.3,
#   'open': 14.25,
#   'high': 14.25,
#   'low': 14.0,
#   'close': 14.15,
#   'average': 14.11,
#   'adOpen': 3.441,
#   'adHigh': 3.441,
#   'adLow': 3.381,
#   'adClose': 3.417,
#   'adAverage': 3.408,
#   'nmVolume': 65030.0,
#   'nmValue': 917324500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.15,
#   'adChange': -0.0362,
#   'pctChange': -1.049},
#  {'code': 'VND',
#   'date': '2020-02-12',
#   'time': '15:02:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.15,
#   'ceilingPrice': 15.1,
#   'floorPrice': 13.2,
#   'open': 14.0,
#   'high': 14.3,
#   'low': 13.95,
#   'close': 14.3,
#   'average': 14.11,
#   'adOpen': 3.381,
#   'adHigh': 3.453,
#   'adLow': 3.369,
#   'adClose': 3.453,
#   'adAverage': 3.408,
#   'nmVolume': 313910.0,
#   'nmValue': 4428344500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.15,
#   'adChange': 0.0362,
#   'pctChange': 1.0601},
#  {'code': 'VND',
#   'date': '2020-02-11',
#   'time': '15:02:04',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 13.85,
#   'ceilingPrice': 14.8,
#   'floorPrice': 12.9,
#   'open': 13.75,
#   'high': 14.15,
#   'low': 13.7,
#   'close': 14.15,
#   'average': 13.88,
#   'adOpen': 3.32,
#   'adHigh': 3.417,
#   'adLow': 3.308,
#   'adClose': 3.417,
#   'adAverage': 3.352,
#   'nmVolume': 173340.0,
#   'nmValue': 2406612000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.3,
#   'adChange': 0.0724,
#   'pctChange': 2.1661},
#  {'code': 'VND',
#   'date': '2020-02-10',
#   'time': '15:02:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.05,
#   'ceilingPrice': 15.0,
#   'floorPrice': 13.1,
#   'open': 13.85,
#   'high': 14.0,
#   'low': 13.8,
#   'close': 13.85,
#   'average': 13.87,
#   'adOpen': 3.344,
#   'adHigh': 3.381,
#   'adLow': 3.333,
#   'adClose': 3.344,
#   'adAverage': 3.35,
#   'nmVolume': 31640.0,
#   'nmValue': 438779500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.2,
#   'adChange': -0.0483,
#   'pctChange': -1.4235},
#  {'code': 'VND',
#   'date': '2020-02-07',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.1,
#   'ceilingPrice': 15.05,
#   'floorPrice': 13.15,
#   'open': 14.0,
#   'high': 14.2,
#   'low': 13.8,
#   'close': 14.05,
#   'average': 14.0,
#   'adOpen': 3.381,
#   'adHigh': 3.429,
#   'adLow': 3.333,
#   'adClose': 3.393,
#   'adAverage': 3.381,
#   'nmVolume': 158540.0,
#   'nmValue': 2220198000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.05,
#   'adChange': -0.0121,
#   'pctChange': -0.3546},
#  {'code': 'VND',
#   'date': '2020-02-06',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.1,
#   'ceilingPrice': 15.05,
#   'floorPrice': 13.15,
#   'open': 13.35,
#   'high': 14.2,
#   'low': 13.35,
#   'close': 14.1,
#   'average': 13.86,
#   'adOpen': 3.224,
#   'adHigh': 3.429,
#   'adLow': 3.224,
#   'adClose': 3.405,
#   'adAverage': 3.347,
#   'nmVolume': 210290.0,
#   'nmValue': 2915488000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.0,
#   'adChange': 0.0,
#   'pctChange': 0.0},
#  {'code': 'VND',
#   'date': '2020-02-05',
#   'time': '15:02:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.0,
#   'ceilingPrice': 14.95,
#   'floorPrice': 13.05,
#   'open': 13.9,
#   'high': 14.1,
#   'low': 13.7,
#   'close': 14.1,
#   'average': 13.93,
#   'adOpen': 3.357,
#   'adHigh': 3.405,
#   'adLow': 3.308,
#   'adClose': 3.405,
#   'adAverage': 3.364,
#   'nmVolume': 104530.0,
#   'nmValue': 1455639000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.1,
#   'adChange': 0.0241,
#   'pctChange': 0.7143},
#  {'code': 'VND',
#   'date': '2020-02-04',
#   'time': '15:02:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.0,
#   'ceilingPrice': 14.95,
#   'floorPrice': 13.05,
#   'open': 14.0,
#   'high': 14.0,
#   'low': 13.35,
#   'close': 14.0,
#   'average': 13.66,
#   'adOpen': 3.381,
#   'adHigh': 3.381,
#   'adLow': 3.224,
#   'adClose': 3.381,
#   'adAverage': 3.299,
#   'nmVolume': 617580.0,
#   'nmValue': 8434395000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.0,
#   'adChange': 0.0,
#   'pctChange': 0.0},
#  {'code': 'VND',
#   'date': '2020-02-03',
#   'time': '15:02:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.7,
#   'ceilingPrice': 15.7,
#   'floorPrice': 13.7,
#   'open': 14.55,
#   'high': 14.55,
#   'low': 13.7,
#   'close': 14.0,
#   'average': 13.88,
#   'adOpen': 3.514,
#   'adHigh': 3.514,
#   'adLow': 3.308,
#   'adClose': 3.381,
#   'adAverage': 3.352,
#   'nmVolume': 854260.0,
#   'nmValue': 11860393000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.7,
#   'adChange': -0.1691,
#   'pctChange': -4.7619},
#  {'code': 'VND',
#   'date': '2020-01-31',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.95,
#   'ceilingPrice': 15.95,
#   'floorPrice': 13.95,
#   'open': 14.5,
#   'high': 14.9,
#   'low': 14.3,
#   'close': 14.7,
#   'average': 14.58,
#   'adOpen': 3.502,
#   'adHigh': 3.598,
#   'adLow': 3.453,
#   'adClose': 3.55,
#   'adAverage': 3.521,
#   'nmVolume': 271930.0,
#   'nmValue': 3965576000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.25,
#   'adChange': -0.0604,
#   'pctChange': -1.6722},
#  {'code': 'VND',
#   'date': '2020-01-30',
#   'time': '15:01:01',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 15.1,
#   'ceilingPrice': 16.15,
#   'floorPrice': 14.05,
#   'open': 15.0,
#   'high': 15.0,
#   'low': 14.5,
#   'close': 14.95,
#   'average': 14.76,
#   'adOpen': 3.623,
#   'adHigh': 3.623,
#   'adLow': 3.502,
#   'adClose': 3.61,
#   'adAverage': 3.565,
#   'nmVolume': 217470.0,
#   'nmValue': 3210281000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.15,
#   'adChange': -0.0362,
#   'pctChange': -0.9934},
#  {'code': 'VND',
#   'date': '2020-01-22',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.5,
#   'ceilingPrice': 15.5,
#   'floorPrice': 13.5,
#   'open': 14.6,
#   'high': 15.1,
#   'low': 14.5,
#   'close': 15.1,
#   'average': 14.84,
#   'adOpen': 3.526,
#   'adHigh': 3.647,
#   'adLow': 3.502,
#   'adClose': 3.647,
#   'adAverage': 3.584,
#   'nmVolume': 441020.0,
#   'nmValue': 6546788000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.6,
#   'adChange': 0.1449,
#   'pctChange': 4.1379},
#  {'code': 'VND',
#   'date': '2020-01-21',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.45,
#   'ceilingPrice': 15.45,
#   'floorPrice': 13.45,
#   'open': 14.5,
#   'high': 14.5,
#   'low': 14.4,
#   'close': 14.5,
#   'average': 14.46,
#   'adOpen': 3.502,
#   'adHigh': 3.502,
#   'adLow': 3.478,
#   'adClose': 3.502,
#   'adAverage': 3.492,
#   'nmVolume': 151950.0,
#   'nmValue': 2196620500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.05,
#   'adChange': 0.0121,
#   'pctChange': 0.346},
#  {'code': 'VND',
#   'date': '2020-01-20',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.45,
#   'ceilingPrice': 15.45,
#   'floorPrice': 13.45,
#   'open': 14.3,
#   'high': 14.55,
#   'low': 14.3,
#   'close': 14.45,
#   'average': 14.47,
#   'adOpen': 3.453,
#   'adHigh': 3.514,
#   'adLow': 3.453,
#   'adClose': 3.49,
#   'adAverage': 3.494,
#   'nmVolume': 52730.0,
#   'nmValue': 762967500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.0,
#   'adChange': 0.0,
#   'pctChange': 0.0},
#  {'code': 'VND',
#   'date': '2020-01-17',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.4,
#   'ceilingPrice': 15.4,
#   'floorPrice': 13.4,
#   'open': 14.45,
#   'high': 14.45,
#   'low': 14.0,
#   'close': 14.45,
#   'average': 14.36,
#   'adOpen': 3.49,
#   'adHigh': 3.49,
#   'adLow': 3.381,
#   'adClose': 3.49,
#   'adAverage': 3.468,
#   'nmVolume': 198600.0,
#   'nmValue': 2852256000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.05,
#   'adChange': 0.0121,
#   'pctChange': 0.3472},
#  {'code': 'VND',
#   'date': '2020-01-16',
#   'time': '15:01:01',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.2,
#   'ceilingPrice': 15.15,
#   'floorPrice': 13.25,
#   'open': 14.35,
#   'high': 14.4,
#   'low': 14.1,
#   'close': 14.4,
#   'average': 14.33,
#   'adOpen': 3.465,
#   'adHigh': 3.478,
#   'adLow': 3.405,
#   'adClose': 3.478,
#   'adAverage': 3.461,
#   'nmVolume': 128120.0,
#   'nmValue': 1836308000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.2,
#   'adChange': 0.0483,
#   'pctChange': 1.4085},
#  {'code': 'VND',
#   'date': '2020-01-15',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.25,
#   'ceilingPrice': 15.2,
#   'floorPrice': 13.3,
#   'open': 14.25,
#   'high': 14.35,
#   'low': 14.15,
#   'close': 14.2,
#   'average': 14.24,
#   'adOpen': 3.441,
#   'adHigh': 3.465,
#   'adLow': 3.417,
#   'adClose': 3.429,
#   'adAverage': 3.439,
#   'nmVolume': 109910.0,
#   'nmValue': 1565597500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.05,
#   'adChange': -0.0121,
#   'pctChange': -0.3509},
#  {'code': 'VND',
#   'date': '2020-01-14',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.3,
#   'ceilingPrice': 15.3,
#   'floorPrice': 13.3,
#   'open': 14.05,
#   'high': 14.35,
#   'low': 14.05,
#   'close': 14.25,
#   'average': 14.27,
#   'adOpen': 3.393,
#   'adHigh': 3.465,
#   'adLow': 3.393,
#   'adClose': 3.441,
#   'adAverage': 3.446,
#   'nmVolume': 116130.0,
#   'nmValue': 1657607000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.05,
#   'adChange': -0.0121,
#   'pctChange': -0.3497},
#  {'code': 'VND',
#   'date': '2020-01-13',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.3,
#   'ceilingPrice': 15.3,
#   'floorPrice': 13.3,
#   'open': 14.3,
#   'high': 14.35,
#   'low': 14.2,
#   'close': 14.3,
#   'average': 14.29,
#   'adOpen': 3.453,
#   'adHigh': 3.465,
#   'adLow': 3.429,
#   'adClose': 3.453,
#   'adAverage': 3.451,
#   'nmVolume': 109370.0,
#   'nmValue': 1563394000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.0,
#   'adChange': 0.0,
#   'pctChange': 0.0},
#  {'code': 'VND',
#   'date': '2020-01-10',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.25,
#   'ceilingPrice': 15.2,
#   'floorPrice': 13.3,
#   'open': 14.25,
#   'high': 14.3,
#   'low': 14.2,
#   'close': 14.3,
#   'average': 14.27,
#   'adOpen': 3.441,
#   'adHigh': 3.453,
#   'adLow': 3.429,
#   'adClose': 3.453,
#   'adAverage': 3.446,
#   'nmVolume': 89810.0,
#   'nmValue': 1281179500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.05,
#   'adChange': 0.0121,
#   'pctChange': 0.3509},
#  {'code': 'VND',
#   'date': '2020-01-09',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.1,
#   'ceilingPrice': 15.05,
#   'floorPrice': 13.15,
#   'open': 14.1,
#   'high': 14.25,
#   'low': 14.1,
#   'close': 14.25,
#   'average': 14.2,
#   'adOpen': 3.405,
#   'adHigh': 3.441,
#   'adLow': 3.405,
#   'adClose': 3.441,
#   'adAverage': 3.429,
#   'nmVolume': 92680.0,
#   'nmValue': 1315919000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.15,
#   'adChange': 0.0362,
#   'pctChange': 1.0638},
#  {'code': 'VND',
#   'date': '2020-01-08',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.3,
#   'ceilingPrice': 15.3,
#   'floorPrice': 13.3,
#   'open': 14.1,
#   'high': 14.15,
#   'low': 13.8,
#   'close': 14.1,
#   'average': 13.97,
#   'adOpen': 3.405,
#   'adHigh': 3.417,
#   'adLow': 3.333,
#   'adClose': 3.405,
#   'adAverage': 3.374,
#   'nmVolume': 233880.0,
#   'nmValue': 3267279500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.2,
#   'adChange': -0.0483,
#   'pctChange': -1.3986},
#  {'code': 'VND',
#   'date': '2020-01-07',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.3,
#   'ceilingPrice': 15.3,
#   'floorPrice': 13.3,
#   'open': 14.3,
#   'high': 14.3,
#   'low': 14.1,
#   'close': 14.3,
#   'average': 14.27,
#   'adOpen': 3.453,
#   'adHigh': 3.453,
#   'adLow': 3.405,
#   'adClose': 3.453,
#   'adAverage': 3.446,
#   'nmVolume': 68060.0,
#   'nmValue': 970935000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.0,
#   'adChange': 0.0,
#   'pctChange': 0.0},
#  {'code': 'VND',
#   'date': '2020-01-06',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.4,
#   'ceilingPrice': 15.4,
#   'floorPrice': 13.4,
#   'open': 14.2,
#   'high': 14.4,
#   'low': 14.1,
#   'close': 14.3,
#   'average': 14.27,
#   'adOpen': 3.429,
#   'adHigh': 3.478,
#   'adLow': 3.405,
#   'adClose': 3.453,
#   'adAverage': 3.446,
#   'nmVolume': 149130.0,
#   'nmValue': 2127958000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.1,
#   'adChange': -0.0241,
#   'pctChange': -0.6944},
#  {'code': 'VND',
#   'date': '2020-01-03',
#   'time': '15:01:03',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.45,
#   'ceilingPrice': 15.45,
#   'floorPrice': 13.45,
#   'open': 14.45,
#   'high': 14.45,
#   'low': 14.15,
#   'close': 14.4,
#   'average': 14.34,
#   'adOpen': 3.49,
#   'adHigh': 3.49,
#   'adLow': 3.417,
#   'adClose': 3.478,
#   'adAverage': 3.463,
#   'nmVolume': 163940.0,
#   'nmValue': 2351222000.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': -0.05,
#   'adChange': -0.0121,
#   'pctChange': -0.346},
#  {'code': 'VND',
#   'date': '2020-01-02',
#   'time': '15:01:02',
#   'floor': 'HOSE',
#   'type': 'STOCK',
#   'basicPrice': 14.4,
#   'ceilingPrice': 15.4,
#   'floorPrice': 13.4,
#   'open': 14.05,
#   'high': 14.45,
#   'low': 14.05,
#   'close': 14.45,
#   'average': 14.3,
#   'adOpen': 3.393,
#   'adHigh': 3.49,
#   'adLow': 3.393,
#   'adClose': 3.49,
#   'adAverage': 3.453,
#   'nmVolume': 58580.0,
#   'nmValue': 837957500.0,
#   'ptVolume': 0.0,
#   'ptValue': 0.0,
#   'change': 0.05,
#   'adChange': 0.0121,
#   'pctChange': 0.3472}]

# %% [markdown]
# Transform Json to Pandas DataFrame

# %%
data = pd.DataFrame(data)
data.head()
# Out:
#   code        date      time floor   type  basicPrice  ceilingPrice  \
# 0  VND  2022-04-08  15:04:02  HOSE  STOCK        35.0         37.45
# 1  VND  2022-04-07  15:04:01  HOSE  STOCK        35.5         37.95
# 2  VND  2022-04-06  15:04:02  HOSE  STOCK        34.6         37.00
# 3  VND  2022-04-05  15:04:02  HOSE  STOCK        33.9         36.25
# 4  VND  2022-04-04  15:04:02  HOSE  STOCK        31.7         33.90
#
#    floorPrice  open  high  ...  adLow  adClose  adAverage    nmVolume  \
# 0       32.55  35.0  36.0  ...  34.55     35.1      35.16  17989300.0
# 1       33.05  35.5  37.0  ...  35.00     35.0      36.02  23236900.0
# 2       32.20  34.0  36.0  ...  34.00     35.5      35.23  18821500.0
# 3       31.55  34.1  36.1  ...  34.10     34.6      35.20  17035800.0
# 4       29.50  32.4  33.9  ...  32.35     33.9      33.55  28162500.0
#
#         nmValue  ptVolume  ptValue  change  adChange  pctChange
# 0  6.325200e+11       0.0      0.0     0.1       0.1     0.2857
# 1  8.369682e+11       0.0      0.0    -0.5      -0.5    -1.4085
# 2  6.630197e+11       0.0      0.0     0.9       0.9     2.6012
# 3  5.996418e+11       0.0      0.0     0.7       0.7     2.0649
# 4  9.447746e+11       0.0      0.0     2.2       2.2     6.9401
#
# [5 rows x 25 columns]

# %%
data.columns
# Out:
# Index(['code', 'date', 'time', 'floor', 'type', 'basicPrice', 'ceilingPrice',
#        'floorPrice', 'open', 'high', 'low', 'close', 'average', 'adOpen',
#        'adHigh', 'adLow', 'adClose', 'adAverage', 'nmVolume', 'nmValue',
#        'ptVolume', 'ptValue', 'change', 'adChange', 'pctChange'],
#       dtype='object')

# %%
data_clean = data[['code', 'date', 'floor', 'close','nmVolume', 'nmValue', 'change', 'pctChange']]
data_clean['date'] = pd.to_datetime(data_clean['date'])
data_clean.set_index('code',inplace=True)
data_clean
# Out:
# <ipython-input-43-90fc60bfda89>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            date floor  close    nmVolume       nmValue  change  pctChange
# code
# VND  2022-04-08  HOSE  35.10  17989300.0  6.325200e+11    0.10     0.2857
# VND  2022-04-07  HOSE  35.00  23236900.0  8.369682e+11   -0.50    -1.4085
# VND  2022-04-06  HOSE  35.50  18821500.0  6.630197e+11    0.90     2.6012
# VND  2022-04-05  HOSE  34.60  17035800.0  5.996418e+11    0.70     2.0649
# VND  2022-04-04  HOSE  33.90  28162500.0  9.447746e+11    2.20     6.9401
# ...         ...   ...    ...         ...           ...     ...        ...
# VND  2020-01-08  HOSE  14.10    233880.0  3.267280e+09   -0.20    -1.3986
# VND  2020-01-07  HOSE  14.30     68060.0  9.709350e+08    0.00     0.0000
# VND  2020-01-06  HOSE  14.30    149130.0  2.127958e+09   -0.10    -0.6944
# VND  2020-01-03  HOSE  14.40    163940.0  2.351222e+09   -0.05    -0.3460
# VND  2020-01-02  HOSE  14.45     58580.0  8.379575e+08    0.05     0.3472
#
# [560 rows x 7 columns]

# %%
data_clean.describe()
# Out:
#             close      nmVolume       nmValue      change   pctChange
# count  560.000000  5.600000e+02  5.600000e+02  560.000000  560.000000
# mean    33.853661  4.482693e+06  2.081525e+11    0.156518    0.460874
# std     22.143207  4.342875e+06  2.408084e+11    1.324064    3.005631
# min     10.700000  3.164000e+04  4.387795e+08   -5.000000   -9.894700
# 25%     13.650000  8.095550e+05  1.059096e+10   -0.262500   -1.153550
# 50%     28.850000  3.757900e+06  1.369207e+11    0.050000    0.173400
# 75%     50.600000  6.552900e+06  3.334973e+11    0.600000    1.970600
# max     85.200000  3.259770e+07  1.124438e+12    5.500000    9.933800

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 560 entries, VND to VND
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       560 non-null    datetime64[ns]
#  1   floor      560 non-null    object
#  2   close      560 non-null    float64
#  3   nmVolume   560 non-null    float64
#  4   nmValue    560 non-null    float64
#  5   change     560 non-null    float64
#  6   pctChange  560 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 35.0+ KB

# %%
data_clean.isnull().sum()
# Out:
# date         0
# floor        0
# close        0
# nmVolume     0
# nmValue      0
# change       0
# pctChange    0
# dtype: int64

# %%
def make_graph(stock_data):
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing = .05) #, subplot_titles=("Historical Price", "Historical Volume")
    fig.add_trace(go.Scatter(x=data_clean.date, y=data_clean.close.astype("float"), name="Price"), row=1, col=1)
    fig.add_trace(go.Bar(x=data_clean.date, y=data_clean.nmVolume.astype("float"), name="Volume"), row=2, col=1)
#     fig.update_xaxes(title_text="Date", rangeslider= {'visible':False},row=1, col=1)
    fig.update_xaxes(title_text="Date",rangeslider= {'visible':True}, row=2, col=1)
#     fig.update_yaxes(title_text="Price", row=1, col=1)
#     fig.update_yaxes(title_text="Volume", row=2, col=1)
    fig.update_layout(showlegend=True,
    height=900,
    title='stock',
    xaxis_rangeslider_visible=False)
    fig.show()

# %%
make_graph(data_clean)

# %% [markdown]
# ## Working with AWS S3

# %%
import boto3
from io import StringIO, BytesIO

# %%
# key_file  = pd.read_csv('D:/new_user_credentials.csv')
# ACCESS_KEY = key_file['Access key ID']
# SECRET_KEY = key_file['Secret access key']

# %%
# client = boto3.client(
# 's3',
# aws_access_key_id=ACCESS_KEY,
# aws_secret_access_key=SECRET_KEY)

# %%
bucket_name = 'stock-data-cuongnm'
# s3 = boto3.resource(
#     's3',
#     region_name='ap-southeast-1',
#     aws_access_key_id=ACCESS_KEY,
#     aws_secret_access_key=SECRET_KEY
# )
s3 = boto3.resource('s3')
bucket = s3.Bucket(bucket_name)

# %%
for obj in bucket.objects.all():
    print(obj.key)
# Out:
# TCB_stock_data_from_2020-01-01_to_2022-04-10.csv

# %%
print(bucket.objects.all())
# Out:
# s3.Bucket.objectsCollection(s3.Bucket(name='stock-data-cuongnm'), s3.ObjectSummary)

# %% [markdown]
# ### Write file to S3

# %%
key = f'{ticker}_stock_data_from_{start_date}_to_{end_date}.csv' #.parquet
key
# Out:
# 'VND_stock_data_from_2020-01-01_to_2022-04-10.csv'

# %%
out_buffer = StringIO() #BytesIO , StringIO
data_clean.to_csv(out_buffer) #to_parquet
bucket.put_object(Body=out_buffer.getvalue(), Key=key)
# Out:
# s3.Object(bucket_name='stock-data-cuongnm', key='VND_stock_data_from_2020-01-01_to_2022-04-10.csv')

# %% [markdown]
# ### Read file from S3

# %%
bucket_obj = bucket.objects.filter(Prefix = 'VND')
objects = [obj for obj in bucket_obj]
objects
# Out:
# [s3.ObjectSummary(bucket_name='stock-data-cuongnm', key='VND_stock_data_from_2020-01-01_to_2022-04-10.csv')]

# %%
for obj in bucket.objects.all():
    print(obj.key)
# Out:
# TCB_stock_data_from_2020-01-01_to_2022-04-10.csv
# VND_stock_data_from_2020-01-01_to_2022-04-10.csv

# %%
csv_obj = bucket.Object(key='TCB_stock_data_from_2020-01-01_to_2022-04-10.csv').get().get('Body').read().decode('utf-8')

# %%
csv_obj[:100]
# Out:
# 'code,date,floor,close,nmVolume,nmValue,change,pctChange\r\nTCB,2022-04-08,HOSE,48.85,7030100.0,3443611'

# %%
data = StringIO(csv_obj)
df = pd.read_csv(data,delimiter = ',')

# %%
df.head()
# Out:
#   code        date floor  close   nmVolume       nmValue  change  pctChange
# 0  TCB  2022-04-08  HOSE  48.85  7030100.0  3.443611e+11   -0.45    -0.9128
# 1  TCB  2022-04-07  HOSE  49.30  5971000.0  2.976459e+11   -0.60    -1.2024
# 2  TCB  2022-04-06  HOSE  49.90  9012200.0  4.432822e+11    0.85     1.7329
# 3  TCB  2022-04-05  HOSE  49.05  5803000.0  2.856016e+11   -0.60    -1.2085
# 4  TCB  2022-04-04  HOSE  49.65  9775600.0  4.881631e+11   -0.65    -1.2922
