# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import datetime as dt
import re
import json
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
#https://dstock.vndirect.com.vn/lich-su-gia/TCB
ticker = 'TCB'
start_date = '2014-01-01'
end_date = '2021-12-17'
delta = dt.datetime.strptime(end_date, '%Y-%m-%d') - dt.datetime.strptime(start_date, '%Y-%m-%d')

# %%
price_api = f'https://finfo-api.vndirect.com.vn/v4/stock_prices?sort=date&q=code:{ticker}~date:gte:{start_date}~date:lte:{end_date}&size={delta.days+1}&page=1'

# %%
HEADERS = {'User-Agent': 'Mozilla'}
res = requests.get(price_api, headers=HEADERS)
data = res.json()['data']  
data = pd.DataFrame(data)
data.head()
# Out:
#   code        date      time floor   type  basicPrice  ceilingPrice  \
# 0  TCB  2021-12-17  15:12:03  HOSE  STOCK       49.85          53.3
# 1  TCB  2021-12-16  15:12:03  HOSE  STOCK       50.20          53.7
# 2  TCB  2021-12-15  15:12:03  HOSE  STOCK       50.10          53.6
# 3  TCB  2021-12-14  15:12:03  HOSE  STOCK       50.00          53.5
# 4  TCB  2021-12-13  15:12:02  HOSE  STOCK       50.20          53.7
# 5  TCB  2021-12-10  15:12:03  HOSE  STOCK       50.40          53.9
# 6  TCB  2021-12-09  15:12:03  HOSE  STOCK       50.00          53.5
# 7  TCB  2021-12-08  15:12:01  HOSE  STOCK       50.00          53.5
# 8  TCB  2021-12-07  15:12:03  HOSE  STOCK       49.00          52.4
# 9  TCB  2021-12-06  15:12:02  HOSE  STOCK       50.20          53.7
#
#    floorPrice  open  high  ...  adLow  adClose  adAverage    nmVolume  \
# 0        46.4  50.0  50.1  ...  49.80    49.85      49.90   7903900.0
# 1        46.7  50.5  50.5  ...  49.85    49.85      50.01   6325600.0
# 2        46.6  50.3  50.8  ...  49.95    50.20      50.26   6818200.0
# 3        46.5  50.0  50.8  ...  49.85    50.10      50.21   7138200.0
# 4        46.7  50.3  50.4  ...  49.95    50.00      50.11   7440600.0
# 5        46.9  50.5  50.9  ...  50.10    50.20      50.47   7507300.0
# 6        46.5  50.0  50.4  ...  49.85    50.40      50.07   5203500.0
# 7        46.5  50.2  50.8  ...  49.90    50.00      50.13   7649900.0
# 8        45.6  49.6  50.3  ...  49.35    50.00      49.68   8982100.0
# 9        46.7  50.3  51.0  ...  48.65    49.00      49.71  22907100.0
#
#         nmValue   ptVolume       ptValue  change  adChange  pctChange
# 0  3.943674e+11  9456300.0  4.801119e+11    0.00      0.00     0.0000
# 1  3.163190e+11   150000.0  7.915000e+09   -0.35     -0.35    -0.6972
# 2  3.426563e+11   780300.0  3.978658e+10    0.10      0.10     0.1996
# 3  3.584425e+11  2077500.0  1.069588e+11    0.10      0.10     0.2000
# 4  3.728229e+11  1365000.0  6.811800e+10   -0.20     -0.20    -0.3984
# 5  3.789166e+11   835000.0  4.146950e+10   -0.20     -0.20    -0.3968
# 6  2.605408e+11  1023100.0  5.179235e+10    0.40      0.40     0.8000
# 7  3.834616e+11   377400.0  2.013015e+10    0.00      0.00     0.0000
# 8  4.462306e+11   710000.0  3.479000e+10    1.00      1.00     2.0408
# 9  1.138768e+12   339500.0  1.798950e+10   -1.20     -1.20    -2.3904
#
# [10 rows x 25 columns]

# %%
data.columns
# Out:
# Index(['code', 'date', 'time', 'floor', 'type', 'basicPrice', 'ceilingPrice',
#        'floorPrice', 'open', 'high', 'low', 'close', 'average', 'adOpen',
#        'adHigh', 'adLow', 'adClose', 'adAverage', 'nmVolume', 'nmValue',
#        'ptVolume', 'ptValue', 'change', 'adChange', 'pctChange'],
#       dtype='object')

# %%
data_clean = data[['code', 'date', 'floor', 'close','nmVolume', 'nmValue', 'change', 'pctChange']]
data_clean['date'] = pd.to_datetime(data_clean['date'])
data_clean.set_index('code',inplace=True)
data_clean
# Out:
# <ipython-input-82-90fc60bfda89>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['date'] = pd.to_datetime(data_clean['date'])
#            date floor   close   nmVolume       nmValue  change  pctChange
# code
# TCB  2021-12-17  HOSE   49.85  7903900.0  3.943674e+11    0.00     0.0000
# TCB  2021-12-16  HOSE   49.85  6325600.0  3.163190e+11   -0.35    -0.6972
# TCB  2021-12-15  HOSE   50.20  6818200.0  3.426563e+11    0.10     0.1996
# TCB  2021-12-14  HOSE   50.10  7138200.0  3.584425e+11    0.10     0.2000
# TCB  2021-12-13  HOSE   50.00  7440600.0  3.728229e+11   -0.20    -0.3984
# ...         ...   ...     ...        ...           ...     ...        ...
# TCB  2018-06-08  HOSE  105.20  2008500.0  2.085462e+11    6.80     6.9106
# TCB  2018-06-07  HOSE   98.40  1376540.0  1.335181e+11    6.40     6.9565
# TCB  2018-06-06  HOSE   92.00  1605480.0  1.492729e+11   -4.00    -4.1667
# TCB  2018-06-05  HOSE   96.00  1357500.0  1.360035e+11   -6.40    -6.2500
# TCB  2018-06-04  HOSE  102.40  2811840.0  2.881918e+11  -25.60   -20.0000
#
# [891 rows x 7 columns]

# %%
data_clean.describe()
# Out:
#             close      nmVolume       nmValue      change   pctChange
# count  891.000000  8.910000e+02  8.910000e+02  891.000000  891.000000
# mean    31.660213  7.079370e+06  2.725411e+11   -0.025701    0.046211
# std     15.487316  8.503838e+06  3.923077e+11    1.226206    2.201371
# min     14.900000  3.287100e+05  9.507343e+09  -25.600000  -20.000000
# 25%     22.000000  1.476155e+06  3.606447e+10   -0.250000   -0.868650
# 50%     25.600000  2.673490e+06  6.373703e+10    0.000000    0.000000
# 75%     39.325000  1.162585e+07  4.335384e+11    0.300000    1.104100
# max    109.000000  5.823550e+07  3.115112e+12    6.800000    6.956500

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, TCB to TCB
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       891 non-null    datetime64[ns]
#  1   floor      891 non-null    object
#  2   close      891 non-null    float64
#  3   nmVolume   891 non-null    float64
#  4   nmValue    891 non-null    float64
#  5   change     891 non-null    float64
#  6   pctChange  891 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 55.7+ KB

# %%
data_clean.isnull().sum()
# Out:
# date         0
# floor        0
# close        0
# nmVolume     0
# nmValue      0
# change       0
# pctChange    0
# dtype: int64

# %%
def make_graph(stock_data):
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing = .05) #, subplot_titles=("Historical Price", "Historical Volume")
    fig.add_trace(go.Scatter(x=data_clean.date, y=data_clean.close.astype("float"), name="Price"), row=1, col=1)
    fig.add_trace(go.Bar(x=data_clean.date, y=data_clean.nmVolume.astype("float"), name="Volume"), row=2, col=1)
#     fig.update_xaxes(title_text="Date", rangeslider= {'visible':False},row=1, col=1)
    fig.update_xaxes(title_text="Date",rangeslider= {'visible':True}, row=2, col=1)
#     fig.update_yaxes(title_text="Price", row=1, col=1)
#     fig.update_yaxes(title_text="Volume", row=2, col=1)
    fig.update_layout(showlegend=True,
    height=900,
    title='stock',
    xaxis_rangeslider_visible=False)
    fig.show()

# %%
make_graph(data_clean)
# Out:
# <div>                            <div id="7b1442f2-1b8f-4fff-9c63-d8b72ffb87e8" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b1442f2-1b8f-4fff-9c63-d8b72ffb87e8")) {                    Plotly.newPlot(                        "7b1442f2-1b8f-4fff-9c63-d8b72ffb87e8",                        [{"name":"Price","type":"scatter","x":["2021-12-17T00:00:00","2021-12-16T00:00:00","2021-12-15T00:00:00","2021-12-14T00:00:00","2021-12-13T00:00:00","2021-12-10T00:00:00","2021-12-09T00:00:00","2021-12-08T00:00:00","2021-12-07T00:00:00","2021-12-06T00:00:00","2021-12-03T00:00:00","2021-12-02T00:00:00","2021-12-01T00:00:00","2021-11-30T00:00:00","2021-11-29T00:00:00","2021-11-26T00:00:00","2021-11-25T00:00:00","2021-11-24T00:00:00","2021-11-23T00:00:00","2021-11-22T00:00:00","2021-11-19T00:00:00","2021-11-18T00:00:00","2021-11-17T00:00:00","2021-11-16T00:00:00","2021-11-15T00:00:00","2021-11-12T00:00:00","2021-11-11T00:00:00","2021-11-10T00:00:00","2021-11-09T00:00:00","2021-11-08T00:00:00","2021-11-05T00:00:00","2021-11-04T00:00:00","2021-11-03T00:00:00","2021-11-02T00:00:00","2021-11-01T00:00:00","2021-10-29T00:00:00","2021-10-28T00:00:00","2021-10-27T00:00:00","2021-10-26T00:00:00","2021-10-25T00:00:00","2021-10-22T00:00:00","2021-10-21T00:00:00","2021-10-20T00:00:00","2021-10-19T00:00:00","2021-10-18T00:00:00","2021-10-15T00:00:00","2021-10-14T00:00:00","2021-10-13T00:00:00","2021-10-12T00:00:00","2021-10-11T00:00:00